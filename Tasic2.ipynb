# %%
import pyontutils
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# %%
df_mtd = pd.read_excel('Data/supplement/Supplementary_Table_10_Full_Metadata.xlsx')
df_morpho = pd.read_excel('Data/supplement/Supplementary_Table_6_Injection_Coordinates.xlsx')
df_celltype = pd.read_excel('Data/supplement/Supplementary_Table_9_Cell_types_markers.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-7a1a209ae8c2> in <module>
#       1 df_mtd = pd.read_excel('Data/supplement/Supplementary_Table_10_Full_Metadata.xlsx')
# ----> 2 df_morpho = pd.read_excel('Supplementary_Table_6_Injection_Coordinates.xlsx')
#       3 df_celltype = pd.read_excel('Supplementary_Table_9_Cell_types_markers.xlsx')
#
# ~/.local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# --> 188             return func(*args, **kwargs)
#     189         return wrapper
#     190     return _deprecate_kwarg
#
# ~/.local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     186                 else:
#     187                     kwargs[new_arg_name] = new_arg_value
# ...

# %%
df_morpho = pd.read_excel('Data/supplement/Supplementary_Table_6_Injection_Coordinates.xlsx')
df_celltype = pd.read_excel('Data/supplement/Supplementary_Table_9_Cell_types_markers.xlsx')

# %%
df_mtd.head().T
# Out:
#                                                                    0  \
# sample_name                                      F1S4_160108_001_A01
# sample_id                                                  527128530
# donor                                                         225675
# sex                                                                M
# age_days                                                          53
# eye_condition                                                 Normal
# genotype                        Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# driver_lines                                        Slc32a1-IRES-Cre
# reporter_lines                                         Ai14(RCL-tdT)
# brain_hemisphere                                                   L
# brain_region                                                    VISp
# brain_subregion                                                 L2/3
# injection_label_direction                               No Injection
# ...

# %%
df_morpho.head().T
# Out:
#                                                          0  \
# donor_id                                            280708
# injection_material                                 CAV-Cre
# injection_type                                  retrograde
# collection_region                                     VISp
# injection_target                                       ACA
# injection_target_category                              CTX
# injection_verified_primary_target                      ACA
# injection_verified_primary_name    anterior cingulate area
# injection_verified_all_targets                ACA, MOs, PL
# injection_tract_labeling                              none
# injection_qc_flags                                      OK
# injection_tract_flag                                    no
# inj_AP                                                0.26
# inj_ML                                               -0.27
# inj_DV                                                 0.8
# ...

# %%
df_celltype.head().T
# Out:
#                                                       0  \
# cluster_id                                            1
# cluster_color                                   #DDACC9
# cluster_label                               Lamp5 Krt73
# class_id                                              1
# class_label                                   GABAergic
# class_color                                     #EF4136
# subclass_id                                           1
# subclass_label                                    Lamp5
# subclass_color                                  #DA808C
# n_cells                                              68
# fraction_ALM                                        0.4
# fraction_VISp                                       0.6
# median_genes                                       9718
# markers_global_specific     Col14a1,Krt73,Scrg1,Tmem45a
# markers_subclass_specific  Csgalnact1,Krt73,Piezo2,Ano3
# markers_vs_siblings                                 NaN
# ...
